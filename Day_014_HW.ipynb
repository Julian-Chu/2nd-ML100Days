# %% [markdown]
# ## 作業
# ### 請使用 application_train.csv, 根據不同的 HOUSETYPE_MODE 對 AMT_CREDIT 繪製 Histogram

# %% [markdown]
# # [作業目標]
# - 試著調整資料, 並利用提供的程式繪製分布圖

# %% [markdown]
# # [作業重點]
# - 如何將列出相異的 HOUSETYPE_MODE 類別 (In[3])
# - 如何依照不同的 HOUSETYPE_MODE 類別指定資料, 並繪製長條圖(.hist())? (In[3])

# %%
# 載入需要的套件
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns # 另一個繪圖-樣式套件

# 忽略警告訊息
# %matplotlib inline
plt.style.use('ggplot')
import warnings
warnings.filterwarnings('ignore')

# 設定 data_path
dir_data = './data/'

# %%
# 讀取檔案
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
app_train.head()
# Out:
# Path of read in data: ./data/application_train.csv
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
# ...

# %%
# 使用不同的 HOUSETYPE_MODE 類別繪製圖形, 並使用 subplot 排版
sub_train = app_train.loc[:, ['TARGET','HOUSETYPE_MODE']]
sub_train['HOUSETYPE_MODE'] = sub_train['HOUSETYPE_MODE'].fillna('unknown')
print(sub_train)
unique_house_type = app_train['HOUSETYPE_MODE'].unique()

print(unique_house_type)
print(app_train.loc[: , ['HOUSETYPE_MODE', 'AMT_CREDIT']])

nrows = len(unique_house_type)
ncols = nrows // 2
print(app_train.loc[: , ['HOUSETYPE_MODE', 'AMT_CREDIT']])

plt.figure(figsize=(10,30))
for i in range(len(unique_house_type)):
    plt.subplot(nrows, ncols, i+1)
    
    """
    Your Code Here
    """
    app_train[app_train['HOUSETYPE_MODE']==]
    app_train.loc[: , 'AMT_CREDIT'].hist()
     
    
    
    plt.title(str(unique_house_type[i]))
plt.show()
# Out:
#         TARGET  HOUSETYPE_MODE
# 0            1  block of flats
# 1            0  block of flats
# 2            0         unknown
# 3            0         unknown
# 4            0         unknown
# 5            0         unknown
# 6            0         unknown
# 7            0         unknown
# 8            0         unknown
# 9            0         unknown
# 10           0         unknown
# 11           0         unknown
# 12           0  block of flats
# 13           0  block of flats
# 14           0  block of flats
# 15           0         unknown
# 16           0         unknown
# 17           0         unknown
# 18           0  block of flats
# 19           0         unknown
# 20           0  block of flats
# 21           0         unknown
# 22           0  block of flats
# 23           0  block of flats
# 24           0  block of flats
# 25           0  block of flats
# 26           1  block of flats
# 27           0         unknown
# 28           0         unknown
# ...
