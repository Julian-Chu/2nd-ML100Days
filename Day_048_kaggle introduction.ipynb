# %% [markdown]
# https://www.kaggle.com/c/data-science-london-scikit-learn/submit

# %%
import pandas as pd
import numpy as np
import copy, time
import warnings
warnings.filterwarnings('ignore')
from IPython.display import display
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

data_path = 'data-science-london-scikit-learn/'
df_train = pd.read_csv(data_path + 'train.csv', header=None)
df_test = pd.read_csv(data_path + 'test.csv', header=None)
df_trainLabel = pd.read_csv(data_path + 'trainLabels.csv', header=None)


print(f' training data shape : {df_train.shape} ')
print(f' training label shape : {df_trainLabel.shape} ')
print(f' testing data shape : {df_test.shape} ')
# Out:
#  training data shape : (1000, 40)
#  training label shape : (1000, 1)
#  testing data shape : (9000, 40)

# %%
# 檢查 DataFrame 空缺值的狀態
def na_check(df_data):
    data_na = (df_data.isnull().sum() / len(df_data)) * 100
    data_na = data_na.drop(data_na[data_na == 0].index).sort_values(ascending=False)
    missing_data = pd.DataFrame({'Missing Ratio' :data_na})
    display(missing_data.head(10))
na_check(df_train)
na_check(df_test)
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %%
df_train.describe()
# Out:
#                 0            1            2            3            4   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.025596    -0.024526    -0.024088    -0.002271     1.092329
# std       1.008282     1.016298     0.979109     0.970575     4.538834
# min      -3.365711    -3.492086    -2.695602    -3.460471   -16.421901
# 25%      -0.669010    -0.693937    -0.698830    -0.617557    -1.801997
# 50%       0.027895    -0.033194     0.008145     0.002327     0.862818
# 75%       0.762520     0.682753     0.661434     0.640743     3.843172
# max       3.326246     3.583870     2.546507     3.088738    17.565345
#
#                 5            6            7            8            9   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.006250     0.497342    -0.037883     0.026391    -0.003597
# std       0.989128     2.118819     2.232256     1.001064     1.013520
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

X, y = df_train, np.ravel(df_trainLabel)
clf = GradientBoostingClassifier
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.4)

# %%
from sklearn.ensemble import RandomForestClassifier
Random_forest = RandomForestClassifier()
Random_forest.fit(X_train, y_train)
Random_forest.predict(X_test)
print(Random_forest.score(X_test, y_test))
# Out:
# 0.8

# %%
res = pd.DataFrame(Random_forest.predict(df_test))
res.columns = ['Solution']
res['Id'] = np.arange(1, res.shape[0]+1)
res = res[['Id', 'Solution']]
print(res)
res.to_csv('res_data-science-london-scikit-learn.csv', index=False)
# Out:
#         Id  Solution
# 0        1         1
# 1        2         0
# 2        3         1
# 3        4         0
# 4        5         0
# 5        6         0
# 6        7         0
# 7        8         0
# 8        9         0
# 9       10         0
# 10      11         1
# 11      12         1
# 12      13         1
# 13      14         0
# 14      15         0
# 15      16         0
# 16      17         0
# 17      18         0
# 18      19         0
# 19      20         1
# 20      21         0
# 21      22         1
# 22      23         0
# 23      24         1
# 24      25         1
# 25      26         1
# 26      27         1
# 27      28         0
# 28      29         1
# 29      30         0
# ...    ...       ...
# 8970  8971         0
# 8971  8972         0
# 8972  8973         1
# 8973  8974         1
# 8974  8975         1
# 8975  8976         1
# 8976  8977         1
# 8977  8978         1
# 8978  8979         1
# 8979  8980         1
# 8980  8981         1
# ...
